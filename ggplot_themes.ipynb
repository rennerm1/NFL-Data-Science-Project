# %% [markdown]
# <a href="https://colab.research.google.com/github/michiWS1920/nfl_data/blob/denice/ggplot_themes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ggplot2 themes https://www.statology.org/best-ggplot2-themes/

# %%
library(datasets)
data(iris)
head(iris,3)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa

# %%
#load ggplot2 library
library(ggplot2)

#create scatterplot
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point() +
  theme_bw()
# Out:
# plot without title

# %%
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point() +
  theme_dark()
# Out:
# plot without title

# %%
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point() +
  theme_void()
# Out:
# plot without title

# %%
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point() +
  theme(
    panel.background = element_rect(fill = "powderblue",
    color = "powderblue",
    size = 0.5, linetype = "solid"),
    panel.grid.major = element_line(size = 0.5, linetype = 'solid', color = "white"),
    panel.grid.minor = element_line(size = 0.25, linetype = 'solid', color = "white")
  )
# Out:
# plot without title

# %%
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point() +
  theme_void()
# Out:
# plot without title

# %%
# Create a new theme
# https://www.datanovia.com/en/blog/ggplot-themes-gallery/#:~:text=GGPlot%20Themes%20Gallery,-kassambara&text=Our%20selection%20of%20best%20ggplot,in%20the%20ggthemes%20R%20package.
theme_bluewhite <- function (base_size = 11, base_family = "") {
    theme_bw() %+replace% 
    theme(
      panel.grid.major  = element_line(color = "white"),
      panel.background = element_rect(fill = "lightblue"),
      panel.border = element_rect(color = "lightblue", fill = NA),
      axis.line = element_line(color = "lightblue"),
      axis.ticks = element_line(color = "lightblue"),
      axis.text = element_text(color = "steelblue")
      )
}

# %%
# Using our new theme
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point() +
  theme_bluewhite()
# Out:
# plot without title

# %%
library(ggplot2)

g_base <- ggplot(mpg) + 
  aes(hwy, cty) + 
  geom_point() +
  labs(x = "Highway MPG", y = "City MPG", title = "Fuel Efficiency")

# Basic plot with default theme
g_base
# Out:
# plot without title

# %%
install.packages("devtools")
library(devtools)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install_github("kassambara/easyGgplot2")

# %%
# http://www.sthda.com/english/wiki/ggplot2-customize-how-to-personalize-easily-ggplot2-graphs-in-r-statistical-software
# ggplot2.customize func to personalize legend, background, axis scales
library(easyGgplot2)

# %%
# data.frame
df <- ToothGrowth
head(df)
# Out:
#   len  supp dose
# 1  4.2 VC   0.5
# 2 11.5 VC   0.5
# 3  7.3 VC   0.5
# 4  5.8 VC   0.5
# 5  6.4 VC   0.5
# 6 10.0 VC   0.5

# %%
# Boxplot using ggplot2 package
p <- ggplot(ToothGrowth, aes(factor(dose), len))+geom_boxplot()
p
# Boxplot using easyGgplot2 package
p<-ggplot2.boxplot(data = ToothGrowth, xName = 'dose',yName = 'len')
p
# Out:
# Error in ggplot2.boxplot(data = ToothGrowth, xName = "dose", yName = "len"): could not find function "ggplot2.boxplot"
# Traceback:
# plot without title

# %%
# Axis ticks labels and orientaion
ggplot2.customize(p,
                xShowTitle = FALSE, yShowTitle = FALSE,
                xTickLabelFont = c(14,"bold", "#993333"),
                yTickLabelFont = c(14,"bold", "#993333"),
                xtickLabelRotation = 45, ytickLabelRotation = 45)
# Hide axis tick labels
ggplot2.customize(p,
                xShowTitle = FALSE, yShowTitle = FALSE,
                xShowTickLabel = FALSE, yShowTickLabel = FALSE)
# Hide axis ticks
ggplot2.customize(p,
                xShowTitle = FALSE, yShowTitle = FALSE,
                xShowTickLabel = FALSE, yShowTickLabel = FALSE,
                hideAxisTicks = TRUE)
# AxisLine : a vector of length 3 indicating the size,
  #the line type and the color of axis lines
ggplot2.customize(p, axisLine = c(1, "solid", "darkblue"))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
