# %% [markdown]
# <a href="https://colab.research.google.com/github/michiWS1920/nfl_data/blob/marius/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
install.packages("googledrive")
library(tidyverse)
library(ggplot2)
library(googledrive)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘proj4’
#
#
# Warning message in install.packages("ggalt"):
# “installation of package ‘proj4’ had non-zero exit status”
# Warning message in install.packages("ggalt"):
# “installation of package ‘ggalt’ had non-zero exit status”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# Error in library(ggalt): there is no package called ‘ggalt’
# Traceback:
#
# 1. library(ggalt)

# %%
pbp_all <- readRDS("NFLdata.rds")

# %%
names(pbp_all)
# Out:
#   [1] "play_id"
#   [2] "game_id"
#   [3] "home_team"
#   [4] "away_team"
#   [5] "posteam"
#   [6] "posteam_type"
#   [7] "defteam"
#   [8] "side_of_field"
#   [9] "yardline_100"
#  [10] "game_date"
#  [11] "quarter_seconds_remaining"
#  [12] "half_seconds_remaining"
#  [13] "game_seconds_remaining"
#  [14] "game_half"
#  [15] "quarter_end"
#  [16] "drive"
#  [17] "sp"
#  [18] "qtr"
#  [19] "down"
#  [20] "goal_to_go"
#  [21] "time"
#  [22] "yrdln"
#  [23] "ydstogo"
#  [24] "ydsnet"
#  [25] "desc"
#  [26] "play_type"
#  [27] "yards_gained"
#  [28] "shotgun"
#  [29] "no_huddle"
#  [30] "qb_dropback"
#  [31] "qb_kneel"
#  [32] "qb_spike"
#  [33] "qb_scramble"
#  [34] "pass_length"
#  [35] "pass_location"
#  [36] "air_yards"
#  [37] "yards_after_catch"
#  [38] "run_location"
#  [39] "run_gap"
#  [40] "field_goal_result"
#  [41] "kick_distance"
#  [42] "extra_point_result"
#  [43] "two_point_conv_result"
#  [44] "home_timeouts_remaining"
#  [45] "away_timeouts_remaining"
#  [46] "timeout"
#  [47] "timeout_team"
#  [48] "td_team"
#  [49] "posteam_timeouts_remaining"
#  [50] "defteam_timeouts_remaining"
#  [51] "total_home_score"
#  [52] "total_away_score"
#  [53] "posteam_score"
#  [54] "defteam_score"
#  [55] "score_differential"
#  [56] "posteam_score_post"
#  [57] "defteam_score_post"
#  [58] "score_differential_post"
#  [59] "no_score_prob"
#  [60] "opp_fg_prob"
#  [61] "opp_safety_prob"
#  [62] "opp_td_prob"
#  [63] "fg_prob"
#  [64] "safety_prob"
#  [65] "td_prob"
#  [66] "extra_point_prob"
#  [67] "two_point_conversion_prob"
#  [68] "ep"
#  [69] "epa"
#  [70] "total_home_epa"
#  [71] "total_away_epa"
#  [72] "total_home_rush_epa"
#  [73] "total_away_rush_epa"
#  [74] "total_home_pass_epa"
#  [75] "total_away_pass_epa"
#  [76] "air_epa"
#  [77] "yac_epa"
#  [78] "comp_air_epa"
#  [79] "comp_yac_epa"
#  [80] "total_home_comp_air_epa"
#  [81] "total_away_comp_air_epa"
#  [82] "total_home_comp_yac_epa"
#  [83] "total_away_comp_yac_epa"
#  [84] "total_home_raw_air_epa"
#  [85] "total_away_raw_air_epa"
#  [86] "total_home_raw_yac_epa"
#  [87] "total_away_raw_yac_epa"
#  [88] "wp"
#  [89] "def_wp"
#  [90] "home_wp"
#  [91] "away_wp"
#  [92] "wpa"
#  [93] "home_wp_post"
#  [94] "away_wp_post"
#  [95] "total_home_rush_wpa"
#  [96] "total_away_rush_wpa"
#  [97] "total_home_pass_wpa"
#  [98] "total_away_pass_wpa"
#  [99] "air_wpa"
# [100] "yac_wpa"
# [101] "comp_air_wpa"
# [102] "comp_yac_wpa"
# [103] "total_home_comp_air_wpa"
# [104] "total_away_comp_air_wpa"
# [105] "total_home_comp_yac_wpa"
# [106] "total_away_comp_yac_wpa"
# [107] "total_home_raw_air_wpa"
# [108] "total_away_raw_air_wpa"
# [109] "total_home_raw_yac_wpa"
# [110] "total_away_raw_yac_wpa"
# [111] "punt_blocked"
# [112] "first_down_rush"
# [113] "first_down_pass"
# [114] "first_down_penalty"
# [115] "third_down_converted"
# [116] "third_down_failed"
# [117] "fourth_down_converted"
# [118] "fourth_down_failed"
# [119] "incomplete_pass"
# [120] "touchback"
# [121] "interception"
# [122] "punt_inside_twenty"
# [123] "punt_in_endzone"
# [124] "punt_out_of_bounds"
# [125] "punt_downed"
# [126] "punt_fair_catch"
# [127] "kickoff_inside_twenty"
# [128] "kickoff_in_endzone"
# [129] "kickoff_out_of_bounds"
# [130] "kickoff_downed"
# [131] "kickoff_fair_catch"
# [132] "fumble_forced"
# [133] "fumble_not_forced"
# [134] "fumble_out_of_bounds"
# [135] "solo_tackle"
# [136] "safety"
# [137] "penalty"
# [138] "tackled_for_loss"
# [139] "fumble_lost"
# [140] "own_kickoff_recovery"
# [141] "own_kickoff_recovery_td"
# [142] "qb_hit"
# [143] "rush_attempt"
# [144] "pass_attempt"
# [145] "sack"
# [146] "touchdown"
# [147] "pass_touchdown"
# [148] "rush_touchdown"
# [149] "return_touchdown"
# [150] "extra_point_attempt"
# [151] "two_point_attempt"
# [152] "field_goal_attempt"
# [153] "kickoff_attempt"
# [154] "punt_attempt"
# [155] "fumble"
# [156] "complete_pass"
# [157] "assist_tackle"
# [158] "lateral_reception"
# [159] "lateral_rush"
# [160] "lateral_return"
# [161] "lateral_recovery"
# [162] "passer_player_id"
# [163] "passer_player_name"
# [164] "receiver_player_id"
# [165] "receiver_player_name"
# [166] "rusher_player_id"
# [167] "rusher_player_name"
# [168] "lateral_receiver_player_id"
# [169] "lateral_receiver_player_name"
# [170] "lateral_rusher_player_id"
# [171] "lateral_rusher_player_name"
# [172] "lateral_sack_player_id"
# [173] "lateral_sack_player_name"
# [174] "interception_player_id"
# [175] "interception_player_name"
# [176] "lateral_interception_player_id"
# [177] "lateral_interception_player_name"
# [178] "punt_returner_player_id"
# [179] "punt_returner_player_name"
# [180] "lateral_punt_returner_player_id"
# [181] "lateral_punt_returner_player_name"
# [182] "kickoff_returner_player_name"
# [183] "kickoff_returner_player_id"
# [184] "lateral_kickoff_returner_player_id"
# [185] "lateral_kickoff_returner_player_name"
# [186] "punter_player_id"
# [187] "punter_player_name"
# [188] "kicker_player_name"
# [189] "kicker_player_id"
# [190] "own_kickoff_recovery_player_id"
# [191] "own_kickoff_recovery_player_name"
# [192] "blocked_player_name"
# [193] "tackle_for_loss_1_player_id"
# [194] "tackle_for_loss_1_player_name"
# [195] "tackle_for_loss_2_player_id"
# [196] "tackle_for_loss_2_player_name"
# [197] "qb_hit_1_player_id"
# [198] "qb_hit_1_player_name"
# [199] "qb_hit_2_player_id"
# [200] "qb_hit_2_player_name"
# [201] "forced_fumble_player_1_team"
# [202] "forced_fumble_player_1_player_id"
# [203] "forced_fumble_player_1_player_name"
# [204] "forced_fumble_player_2_team"
# [205] "forced_fumble_player_2_player_id"
# [206] "forced_fumble_player_2_player_name"
# [207] "solo_tackle_1_team"
# [208] "solo_tackle_2_team"
# [209] "solo_tackle_1_player_id"
# [210] "solo_tackle_2_player_id"
# [211] "solo_tackle_1_player_name"
# [212] "solo_tackle_2_player_name"
# [213] "assist_tackle_1_player_id"
# [214] "assist_tackle_1_player_name"
# [215] "assist_tackle_1_team"
# [216] "assist_tackle_2_player_id"
# [217] "assist_tackle_2_player_name"
# [218] "assist_tackle_2_team"
# [219] "assist_tackle_3_player_id"
# [220] "assist_tackle_3_player_name"
# [221] "assist_tackle_3_team"
# [222] "assist_tackle_4_player_id"
# [223] "assist_tackle_4_player_name"
# [224] "assist_tackle_4_team"
# [225] "pass_defense_1_player_id"
# [226] "pass_defense_1_player_name"
# [227] "pass_defense_2_player_id"
# [228] "pass_defense_2_player_name"
# [229] "fumbled_1_team"
# [230] "fumbled_1_player_id"
# [231] "fumbled_1_player_name"
# [232] "fumbled_2_player_id"
# [233] "fumbled_2_player_name"
# [234] "fumbled_2_team"
# [235] "fumble_recovery_1_team"
# [236] "fumble_recovery_1_yards"
# [237] "fumble_recovery_1_player_id"
# [238] "fumble_recovery_1_player_name"
# [239] "fumble_recovery_2_team"
# [240] "fumble_recovery_2_player_name"
# [241] "return_team"
# [242] "return_yards"
# [243] "penalty_team"
# [244] "penalty_player_id"
# [245] "penalty_player_name"
# [246] "penalty_yards"
# [247] "replay_or_challenge"
# [248] "replay_or_challenge_result"
# [249] "penalty_type"
# [250] "defensive_two_point_attempt"
# [251] "defensive_two_point_conv"
# [252] "defensive_extra_point_attempt"
# [253] "defensive_extra_point_conv"
# [254] "week"
# [255] "season"

# %%
totalPoints <- pbp_all %>% 
 group_by(game_id, season, week) %>%
 summarise(scoreHome = max(total_home_score),
           scoreAway = max(total_away_score)) %>%
 mutate(totalPoints= scoreHome+scoreAway)

 totalPoints
# Out:
# `summarise()` regrouping output by 'game_id', 'season' (override with `.groups` argument)
#      game_id    season week scoreHome scoreAway totalPoints
# 1    2009091000 2009   1    13        10        23
# 2    2009091300 2009   1    19         7        26
# 3    2009091301 2009   1    38        23        61
# 4    2009091302 2009   1    10        36        46
# 5    2009091303 2009   1     7        12        19
# 6    2009091304 2009   1    19        34        53
# 7    2009091305 2009   1     6        24        30
# 8    2009091306 2009   1    14        12        26
# 9    2009091307 2009   1    45        26        71
# 10   2009091308 2009   1    21        34        55
# 11   2009091309 2009   1    16        20        36
# 12   2009091310 2009   1    22        17        39
# 13   2009091311 2009   1    28         0        28
# 14   2009091312 2009   1    21        15        36
# 15   2009091400 2009   1    25        23        48
# 16   2009091401 2009   1    20        24        44
# 17   2009092000 2009   2    28        20        48
# 18   2009092001 2009   2    13        27        40
# 19   2009092002 2009   2    23        31        54
# 20   2009092003 2009   2    17        30        47
# 21   2009092004 2009   2    10        13        23
# 22   2009092005 2009   2    16         9        25
# 23   2009092006 2009   2    22        47        69
# 24   2009092007 2009   2    31        34        65
# 25   2009092008 2009   2     9         7        16
# 26   2009092009 2009   2    32        20        52
# 27   2009092010 2009   2    23        10        33
# 28   2009092011 2009   2    17        14        31
# 29   2009092012 2009   2    27         6        33
# 30   2009092013 2009   2    26        31        57
# ⋮    ⋮          ⋮      ⋮    ⋮         ⋮         ⋮
# 2787 2019122102 2019   16   34        31        65
# 2788 2019122200 2019   16   27        17        44
# 2789 2019122201 2019   16   17        24        41
# 2790 2019122205 2019   16   24        12        36
# 2791 2019122206 2019   16   15        31        46
# 2792 2019122207 2019   16   38         6        44
# 2793 2019122208 2019   16   38        35        73
# 2794 2019122209 2019   16   16        10        26
# 2795 2019122210 2019   16   28        38        66
# 2796 2019122211 2019   16   35        41        76
# 2797 2019122212 2019   16   17         9        26
# 2798 2019122213 2019   16   13        27        40
# 2799 2019122214 2019   16    3        26        29
# 2800 2019122300 2019   16   10        23        33
# 2801 2019122900 2019   17   28        10        38
# 2802 2019122901 2019   17    6        13        19
# 2803 2019122902 2019   17   10        42        52
# 2804 2019122903 2019   17   33        23        56
# 2805 2019122904 2019   17   47        16        63
# 2806 2019122905 2019   17   20        23        43
# 2807 2019122906 2019   17   14        35        49
# 2808 2019122907 2019   17   38        20        58
# 2809 2019122908 2019   17   31        21        52
# 2810 2019122909 2019   17   19        21        40
# 2811 2019122910 2019   17   24        27        51
# 2812 2019122911 2019   17   17        34        51
# 2813 2019122912 2019   17   21        28        49
# 2814 2019122913 2019   17   16        15        31
# 2815 2019122914 2019   17   31        24        55
# 2816 2019122915 2019   17   21        26        47

# %% [markdown]
# Problem: Data doesn't show outcomes for each game at the results of each game directly. First idea -> use score when gam_seconds_reaining ==0 But: Some games have overtime.
#
# -> Use max Values for total_home_score and total_away_score

# %%
points_over_time <- totalPoints %>%
group_by(season, week) %>%
summarise(points_per_season= sum(totalPoints),noGames=n()) %>%
mutate(average_points_per_game=points_per_season/noGames)
# Out:
# `summarise()` regrouping output by 'season' (override with `.groups` argument)
#     season week pps noGames averagePPG
# 1   2009    1   641 16      40.06250
# 2   2009    2   706 16      44.12500
# 3   2009    3   626 16      39.12500
# 4   2009    4   628 14      44.85714
# 5   2009    5   592 14      42.28571
# 6   2009    6   591 14      42.21429
# 7   2009    7   594 13      45.69231
# 8   2009    8   598 13      46.00000
# 9   2009    9   596 13      45.84615
# 10  2009   10   615 15      41.00000
# 11  2009   11   683 16      42.68750
# 12  2009   12   644 16      40.25000
# 13  2009   13   684 16      42.75000
# 14  2009   14   638 16      39.87500
# 15  2009   15   719 16      44.93750
# 16  2009   16   676 16      42.25000
# 17  2009   17   672 16      42.00000
# 18  2010    1   583 16      36.43750
# 19  2010    2   661 16      41.31250
# 20  2010    3   696 16      43.50000
# 21  2010    4   572 14      40.85714
# 22  2010    5   637 14      45.50000
# 23  2010    6   601 14      42.92857
# 24  2010    7   727 14      51.92857
# 25  2010    8   538 13      41.38462
# 26  2010    9   593 13      45.61538
# 27  2010   10   723 14      51.64286
# 28  2010   11   722 16      45.12500
# 29  2010   12   723 16      45.18750
# 30  2010   13   670 16      41.87500
# ⋮   ⋮      ⋮    ⋮   ⋮       ⋮
# 158 2018    5   701 15      46.73333
# 159 2018    6   747 15      49.80000
# 160 2018    7   652 14      46.57143
# 161 2018    8   685 14      48.92857
# 162 2018    9   602 13      46.30769
# 163 2018   10   679 14      48.50000
# 164 2018   11   664 13      51.07692
# 165 2018   12   708 15      47.20000
# 166 2018   13   677 16      42.31250
# 167 2018   14   693 16      43.31250
# 168 2018   15   613 16      38.31250
# 169 2018   16   722 16      45.12500
# 170 2018   17   719 16      44.93750
# 171 2019    1   776 16      48.50000
# 172 2019    2   618 16      38.62500
# 173 2019    3   751 16      46.93750
# 174 2019    4   653 15      43.53333
# 175 2019    5   696 15      46.40000
# 176 2019    6   619 14      44.21429
# 177 2019    7   657 14      46.92857
# 178 2019    8   656 15      43.73333
# 179 2019    9   665 14      47.50000
# 180 2019   10   600 13      46.15385
# 181 2019   11   604 14      43.14286
# 182 2019   12   584 14      41.71429
# 183 2019   13   722 16      45.12500
# 184 2019   14   813 16      50.81250
# 185 2019   15   775 16      48.43750
# 186 2019   16   729 16      45.56250
# 187 2019   17   754 16      47.12500

# %%
g = ggplot(data = POT,
           aes(x = week,
               y = averagePPG)) +
    geom_point() +
    ylim(40,50) + xlim(2009,2019) +
    scale_x_discrete(limits= c(2009:2019))
    g
# Out:
# Warning message:
# “Continuous limits supplied to discrete scale.
# Did you mean `limits = factor(...)` or `scale_*_continuous()`?”
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
#
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %%
POT %>%
  ggplot( aes(x=week, y=averagePPG, group=season)) +
    geom_line()
# Out:
# plot without title

# %%
PassesPerWeek <- pbp_all %>%
filter(pass_attempt==1) %>%
group_by(season,week) %>%
summarize(attempt_passes= sum(pass_attempt), distinct_Games=n_distinct(game_id)) %>%
mutate(attempt_passes_per_game= attempt_passes/distinct_Games)
PassesPerWeek
# Out:
# `summarise()` regrouping output by 'season' (override with `.groups` argument)
#     season week attempt_passes distinct_Games attempt_passes_per_game
# 1   2009    1   1150           16             71.87500
# 2   2009    2   1156           16             72.25000
# 3   2009    3   1103           16             68.93750
# 4   2009    4   1040           14             74.28571
# 5   2009    5    969           14             69.21429
# 6   2009    6    986           14             70.42857
# 7   2009    7    884           13             68.00000
# 8   2009    8    883           13             67.92308
# 9   2009    9    994           13             76.46154
# 10  2009   10   1107           15             73.80000
# 11  2009   11   1141           16             71.31250
# 12  2009   12   1160           16             72.50000
# 13  2009   13   1175           16             73.43750
# 14  2009   14   1087           16             67.93750
# 15  2009   15   1164           16             72.75000
# 16  2009   16   1115           16             69.68750
# 17  2009   17   1064           16             66.50000
# 18  2010    1   1166           16             72.87500
# 19  2010    2   1113           16             69.56250
# 20  2010    3   1156           16             72.25000
# 21  2010    4    995           14             71.07143
# 22  2010    5   1054           14             75.28571
# 23  2010    6   1019           14             72.78571
# 24  2010    7   1036           14             74.00000
# 25  2010    8    979           13             75.30769
# 26  2010    9    930           13             71.53846
# 27  2010   10   1090           14             77.85714
# 28  2010   11   1185           16             74.06250
# 29  2010   12   1152           16             72.00000
# 30  2010   13   1060           16             66.25000
# ⋮   ⋮      ⋮    ⋮              ⋮              ⋮
# 158 2018    5   1188           15             79.20000
# 159 2018    6   1113           15             74.20000
# 160 2018    7   1027           14             73.35714
# 161 2018    8   1042           14             74.42857
# 162 2018    9    973           13             74.84615
# 163 2018   10    999           14             71.35714
# 164 2018   11    940           13             72.30769
# 165 2018   12   1046           15             69.73333
# 166 2018   13   1179           16             73.68750
# 167 2018   14   1180           16             73.75000
# 168 2018   15   1125           16             70.31250
# 169 2018   16   1181           16             73.81250
# 170 2018   17   1120           16             70.00000
# 171 2019    1   1230           16             76.87500
# 172 2019    2   1209           16             75.56250
# 173 2019    3   1206           16             75.37500
# 174 2019    4   1164           15             77.60000
# 175 2019    5   1075           15             71.66667
# 176 2019    6   1041           14             74.35714
# 177 2019    7    988           14             70.57143
# 178 2019    8   1108           15             73.86667
# 179 2019    9   1030           14             73.57143
# 180 2019   10   1040           13             80.00000
# 181 2019   11   1127           14             80.50000
# 182 2019   12    993           14             70.92857
# 183 2019   13   1213           16             75.81250
# 184 2019   14   1195           16             74.68750
# 185 2019   15   1162           16             72.62500
# 186 2019   16   1242           16             77.62500
# 187 2019   17   1190           16             74.37500

# %% [markdown]
# Pass Attempts over Time

# %%
RushPerWeek <- pbp_all %>%
filter(rush_attempt==1) %>%
group_by(season,week) %>%
summarize(attempt_rush= sum(rush_attempt), distinct_Games=n_distinct(game_id)) %>%
mutate(attempt_passes_per_game= attempt_rush/distinct_Games)
RushPerWeek
# Out:
# `summarise()` regrouping output by 'season' (override with `.groups` argument)
#     season week attempt_rush distinct_Games attempt_passes_per_game
# 1   2009    1   840          16             52.50000
# 2   2009    2   866          16             54.12500
# 3   2009    3   889          16             55.56250
# 4   2009    4   753          14             53.78571
# 5   2009    5   759          14             54.21429
# 6   2009    6   780          14             55.71429
# 7   2009    7   718          13             55.23077
# 8   2009    8   741          13             57.00000
# 9   2009    9   657          13             50.53846
# 10  2009   10   821          15             54.73333
# 11  2009   11   891          16             55.68750
# 12  2009   12   862          16             53.87500
# 13  2009   13   886          16             55.37500
# 14  2009   14   919          16             57.43750
# 15  2009   15   877          16             54.81250
# 16  2009   16   943          16             58.93750
# 17  2009   17   902          16             56.37500
# 18  2010    1   842          16             52.62500
# 19  2010    2   900          16             56.25000
# 20  2010    3   845          16             52.81250
# 21  2010    4   740          14             52.85714
# 22  2010    5   746          14             53.28571
# 23  2010    6   793          14             56.64286
# 24  2010    7   753          14             53.78571
# 25  2010    8   702          13             54.00000
# 26  2010    9   716          13             55.07692
# 27  2010   10   751          14             53.64286
# 28  2010   11   827          16             51.68750
# 29  2010   12   874          16             54.62500
# 30  2010   13   908          16             56.75000
# ⋮   ⋮      ⋮    ⋮            ⋮              ⋮
# 158 2018    5   774          15             51.60000
# 159 2018    6   778          15             51.86667
# 160 2018    7   736          14             52.57143
# 161 2018    8   731          14             52.21429
# 162 2018    9   658          13             50.61538
# 163 2018   10   733          14             52.35714
# 164 2018   11   688          13             52.92308
# 165 2018   12   790          15             52.66667
# 166 2018   13   833          16             52.06250
# 167 2018   14   853          16             53.31250
# 168 2018   15   874          16             54.62500
# 169 2018   16   807          16             50.43750
# 170 2018   17   855          16             53.43750
# 171 2019    1   777          16             48.56250
# 172 2019    2   810          16             50.62500
# 173 2019    3   832          16             52.00000
# 174 2019    4   763          15             50.86667
# 175 2019    5   821          15             54.73333
# 176 2019    6   748          14             53.42857
# 177 2019    7   775          14             55.35714
# 178 2019    8   767          15             51.13333
# 179 2019    9   728          14             52.00000
# 180 2019   10   672          13             51.69231
# 181 2019   11   682          14             48.71429
# 182 2019   12   763          14             54.50000
# 183 2019   13   824          16             51.50000
# 184 2019   14   877          16             54.81250
# 185 2019   15   873          16             54.56250
# 186 2019   16   837          16             52.31250
# 187 2019   17   866          16             54.12500

# %% [markdown]
# Rush attempts over time

# %%
points_scored_allowed_home <- pbp_all %>% 
 filter(season==2019) %>%
 select(home_team, away_team, total_home_score, total_away_score, week) %>%
 group_by(home_team, week) %>%
 summarize(scoreHome=max(total_home_score),scoreAway=max(total_away_score)) %>%
 group_by(home_team) %>%
 summarize(scored_points_home=sum(scoreHome),allowed_points_home=sum(scoreAway))

points_scored_allowed_home
# Out:
# `summarise()` regrouping output by 'home_team' (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)
#    home_team scored_points_home allowed_points_home
# 1  ARI       178                234
# 2  ATL       168                201
# 3  BAL       239                149
# 4  BUF       142                134
# 5  CAR       163                227
# 6  CHI       133                146
# 7  CIN       148                222
# 8  CLE       177                192
# 9  DAL       257                158
# 10 DEN       150                143
# 11 DET       188                232
# 12 GB        205                156
# 13 HOU       189                196
# 14 IND       194                157
# 15 JAC       143                192
# 16 KC        212                165
# 17 LA        180                181
# 18 LAC       150                193
# 19 MIA       157                270
# 20 MIN       195                129
# 21 NE        202                120
# 22 NO        227                183
# 23 NYG       153                208
# 24 NYJ       149                156
# 25 OAK       169                185
# 26 PHI       168                134
# 27 PIT       176                137
# 28 SEA       205                229
# 29 SF        259                157
# 30 TB        200                247
# 31 TEN       200                190
# 32 WAS       141                232

# %% [markdown]
# points scored and allowed for 2019 season if a certain team played at home

# %%
points_scored_allowed_away <- pbp_all %>% 
 filter(season==2019) %>%
 select(home_team, away_team, total_home_score, total_away_score, week) %>%
 group_by(away_team, week) %>%
 summarize(scoreHome=max(total_home_score),scoreAway=max(total_away_score)) %>%
 group_by(away_team) %>%
 summarize(scored_points_away=sum(scoreAway),allowed_points_away=sum(scoreHome))

points_scored_allowed_away
# Out:
# `summarise()` regrouping output by 'away_team' (override with `.groups` argument)
#
# `summarise()` ungrouping output (override with `.groups` argument)
#    away_team scored_points_away allowed_points_away
# 1  ARI       183                208
# 2  ATL       213                197
# 3  BAL       292                133
# 4  BUF       172                125
# 5  CAR       177                243
# 6  CHI       147                152
# 7  CIN       131                198
# 8  CLE       158                201
# 9  DAL       177                163
# 10 DEN       132                173
# 11 DET       153                191
# 12 GB        171                157
# 13 HOU       189                189
# 14 IND       165                216
# 15 JAC       157                201
# 16 KC        237                143
# 17 LA        214                182
# 18 LAC       187                152
# 19 MIA       149                224
# 20 MIN       212                174
# 21 NE        218                105
# 22 NO        231                158
# 23 NYG       188                243
# 24 NYJ       127                203
# 25 OAK       144                232
# 26 PHI       217                220
# 27 PIT       113                166
# 28 SEA       200                169
# 29 SF        220                153
# 30 TB        254                202
# 31 TEN       202                141
# 32 WAS       125                203

# %%
points_scored_allowed_season <- left_join(points_scored_allowed_home, points_scored_allowed_away, by= c("home_team" = "away_team")) %>%
rename(team=home_team)%>%
mutate(points_scored =(scored_points_home + scored_points_away), points_allowed = (allowed_points_home+allowed_points_away), difference = (points_scored-points_allowed)) %>%
select(team, points_scored, points_allowed, difference)

points_scored_allowed_season
# Out:
#    team points_scored points_allowed difference
# 1  ARI  361           442             -81
# 2  ATL  381           398             -17
# 3  BAL  531           282             249
# 4  BUF  314           259              55
# 5  CAR  340           470            -130
# 6  CHI  280           298             -18
# 7  CIN  279           420            -141
# 8  CLE  335           393             -58
# 9  DAL  434           321             113
# 10 DEN  282           316             -34
# 11 DET  341           423             -82
# 12 GB   376           313              63
# 13 HOU  378           385              -7
# 14 IND  359           373             -14
# 15 JAC  300           393             -93
# 16 KC   449           308             141
# 17 LA   394           363              31
# 18 LAC  337           345              -8
# 19 MIA  306           494            -188
# 20 MIN  407           303             104
# 21 NE   420           225             195
# 22 NO   458           341             117
# 23 NYG  341           451            -110
# 24 NYJ  276           359             -83
# 25 OAK  313           417            -104
# 26 PHI  385           354              31
# 27 PIT  289           303             -14
# 28 SEA  405           398               7
# 29 SF   479           310             169
# 30 TB   454           449               5
# 31 TEN  402           331              71
# 32 WAS  266           435            -169

# %%
points_scored_allowed_season %>% 
  ggplot(aes(x = team, y = points_scored, points_allowed,)) +
  geom_line(aes(group = team), color = "grey", size = 3) +
  geom_point(size = 5) +
  coord_flip()
# Out:
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# plot without title
